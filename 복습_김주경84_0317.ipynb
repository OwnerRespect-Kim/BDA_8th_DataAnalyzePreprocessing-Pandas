# %%
import seaborn as sns
import pandas as pd
tt = sns.load_dataset('titanic')

# %% [markdown]
# - 저번 시간에 이어 계속해서 데이터 분석에 필요한 기초 문법 진행

# %% [markdown]
# - sort 순서 정렬하기
# - sort_values(col1), 오름, 내림차순 정렬
# - 내림차순 하는 법?
# - sort_values(col1, ascending=False, True)

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.sort_values('age') # 디폴트가 오름차순
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 803         1       3    male  0.42      0      1   8.5167        C   Third
# 755         1       2    male  0.67      1      1  14.5000        S  Second
# 644         1       3  female  0.75      2      1  19.2583        C   Third
# 469         1       3  female  0.75      2      1  19.2583        C   Third
# 78          1       2    male  0.83      0      2  29.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 859         0       3    male   NaN      0      0   7.2292        C   Third
# 863         0       3  female   NaN      8      2  69.5500        S   Third
# 868         0       3    male   NaN      0      0   9.5000        S   Third
# 878         0       3    male   NaN      0      0   7.8958        S   Third
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt.sort_values('age', ascending=False) # 디폴트가 내림차순
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 630         1       1    male  80.0      0      0  30.0000        S  First
# 851         0       3    male  74.0      0      0   7.7750        S  Third
# 493         0       1    male  71.0      0      0  49.5042        C  First
# 96          0       1    male  71.0      0      0  34.6542        C  First
# 116         0       3    male  70.5      0      0   7.7500        Q  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 859         0       3    male   NaN      0      0   7.2292        C  Third
# 863         0       3  female   NaN      8      2  69.5500        S  Third
# 868         0       3    male   NaN      0      0   9.5000        S  Third
# 878         0       3    male   NaN      0      0   7.8958        S  Third
# 888         0       3  female   NaN      1      2  23.4500        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# 여러 개 기준으로 하는 경우
# age, fare 두 가지 경우

tt.sort_values(['age', 'fare']) # age 1순위, fare 2순위
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 803         1       3    male  0.42      0      1    8.5167        C   Third
# 755         1       2    male  0.67      1      1   14.5000        S  Second
# 469         1       3  female  0.75      2      1   19.2583        C   Third
# 644         1       3  female  0.75      2      1   19.2583        C   Third
# 831         1       2    male  0.83      1      1   18.7500        S  Second
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 306         1       1  female   NaN      0      0  110.8833        C   First
# 334         1       1  female   NaN      1      0  133.6500        S   First
# 31          1       1  female   NaN      1      0  146.5208        C   First
# 527         0       1    male   NaN      0      0  221.7792        S   First
# 557         0       1    male   NaN      0      0  227.5250        C   First
#
# ...

# %%
tt.sort_values(['age', 'fare']) # 두 개의 컬럼의 오름, 내림도 지정할 수 있다.
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 803         1       3    male  0.42      0      1    8.5167        C   Third
# 755         1       2    male  0.67      1      1   14.5000        S  Second
# 469         1       3  female  0.75      2      1   19.2583        C   Third
# 644         1       3  female  0.75      2      1   19.2583        C   Third
# 831         1       2    male  0.83      1      1   18.7500        S  Second
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 306         1       1  female   NaN      0      0  110.8833        C   First
# 334         1       1  female   NaN      1      0  133.6500        S   First
# 31          1       1  female   NaN      1      0  146.5208        C   First
# 527         0       1    male   NaN      0      0  221.7792        S   First
# 557         0       1    male   NaN      0      0  227.5250        C   First
#
# ...

# %%
tt.sort_values(['age','fare'], ascending=False)
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 630         1       1  male  80.0      0      0  30.0000        S   First
# 851         0       3  male  74.0      0      0   7.7750        S   Third
# 493         0       1  male  71.0      0      0  49.5042        C   First
# 96          0       1  male  71.0      0      0  34.6542        C   First
# 116         0       3  male  70.5      0      0   7.7500        Q   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 481         0       2  male   NaN      0      0   0.0000        S  Second
# 633         0       1  male   NaN      0      0   0.0000        S   First
# 674         0       2  male   NaN      0      0   0.0000        S  Second
# 732         0       2  male   NaN      0      0   0.0000        S  Second
# 815         0       1  male   NaN      0      0   0.0000        S   First
#
#      who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # 파생변수 여러 개 만들어 보기!

# %%
tt['sex_onehot'] = 0

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
## 성별이 남성인 경우 여성인 경우에 따라서 반복문과 if문을 이용해서 0, 1 매핑하기!
## 값을 지정해서 들어가면 [], loc, iloc으로 값을 찾았다.
## 여성과 남성인지를 확인하기 위해서
## ex) tt.sex.loc[3]

## 이런 새로운 변수를 만들 경우 파생변수를 하나 만들어서 진행할 수 있다.


for i in range(len(tt)):
    if tt.sex.loc[i] == 'male':
        tt['sex_onehot'].loc[i] = 0
    elif tt.sex.loc[i] == 'female':
        tt['sex_onehot'].loc[i] = 1
# Out:
# /var/folders/fs/789w_bnn3h1crkt1ffyqbv700000gn/T/ipykernel_3434/1570591450.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tt['sex_onehot'].loc[i] = 0
# /var/folders/fs/789w_bnn3h1crkt1ffyqbv700000gn/T/ipykernel_3434/1570591450.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tt['sex_onehot'].loc[i] = 1

# %%
print(tt.sex_onehot.value_counts())
# Out:
# sex_onehot
# 0    577
# 1    314
# Name: count, dtype: int64

# %%
print(tt.sex.value_counts())
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# - 파생변수란?
# - 기존에 있는 변수들을 가지고 조합해서 만드는 경우
# - 기존 변수에 사칙연산을 통해서 만들 수도 있고
# - 아예 새로운 식으로 만들 수 있다. (기존변수 또는 파생변수를 이용해서도)

# %%
## ex) 요금 변수에 *100 단위를 맞춘다.

tt.fare*100 # 바로 브로드캐스팅이 되어서 시리즈에서 연산이 된다.
# Out:
# 0       725.00
# 1      7128.33
# 2       792.50
# 3      5310.00
# 4       805.00
#         ...
# 886    1300.00
# 887    3000.00
# 888    2345.00
# 889    3000.00
# 890     775.00
# Name: fare, Length: 891, dtype: float64

# %%
tt['fare_100'] = tt.fare*100

# %% [markdown]
# - 파생변수 만들 수 있는 함수
# - assign() 함수를 이용해서 만들 수 있다.
#
# - assign(변수명 = 조건식, 조건에 맞는 값, 그외 값)

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
import numpy as np
# 넘파이에서 제공하는 np.where 함수를 이용해서 인덱싱하여 해당 값에 조건에 맞는 값을 대입

# %%
tt.assign(fare_cls = np.where(tt['fare'] >= 10, 'H', 'L'))
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
# 새로운 파생변수명 np.where(tt['fare'] >= 10) 조건, 조건에 맞으면 H 아니면 L
fare_cls = np.where(tt['fare'] >= 10, 'H', 'L')

# %%
# 조건에 맞는 인덱스를 호출하는 함수
np.where(tt['fare']>=100)
# Out:
# (array([ 27,  31,  88, 118, 195, 215, 258, 268, 269, 297, 299, 305, 306,
#         307, 311, 318, 319, 325, 332, 334, 337, 341, 373, 377, 380, 390,
#         393, 435, 438, 498, 505, 527, 537, 544, 550, 557, 581, 609, 659,
#         660, 679, 689, 698, 700, 708, 716, 730, 737, 742, 763, 779, 802,
#         856]),)

# %%
tt.loc[27]
# Out:
# survived                 0
# pclass                   1
# sex                   male
# age                   19.0
# sibsp                    3
# parch                    2
# fare                 263.0
# embarked                 S
# class                First
# who                    man
# adult_male            True
# deck                     C
# embark_town    Southampton
# alive                   no
# alone                False
# sex_onehot               0
# fare_100           26300.0
# Name: 27, dtype: object

# %%
#lambda를 사용해서도 가능하다.
tt.assign(fare_cls = lambda x : x['fare_100'] / x['fare'])
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %% [markdown]
# ## group by
# - 집계하는 것
# - 기준 컬럼을 가지고 통계치를 보고 싶은 컬럼의 값을 볼 수 있다.
# - Groupby 하나의 기준 컬럼의 그룹으로 만든다.

# %%
#pclass 1, 2, 3 등급으로 나뉘어져 있음
grouped=tt.groupby('class')

# %%
grouped

# %%
for i, j in grouped: # 클래스를 기준으로 정렬되어 있다!
    print(i)
    print(j.head(10))
# Out:
# First
#     survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 1          1       1  female  38.0      1      0   71.2833        C  First
# 3          1       1  female  35.0      1      0   53.1000        S  First
# 6          0       1    male  54.0      0      0   51.8625        S  First
# 11         1       1  female  58.0      0      0   26.5500        S  First
# 23         1       1    male  28.0      0      0   35.5000        S  First
# 27         0       1    male  19.0      3      2  263.0000        S  First
# 30         0       1    male  40.0      0      0   27.7208        C  First
# 31         1       1  female   NaN      1      0  146.5208        C  First
# 34         0       1    male  28.0      1      0   82.1708        C  First
# 35         0       1    male  42.0      1      0   52.0000        S  First
#
#       who  adult_male deck  embark_town alive  alone  sex_onehot  fare_100
# ...

# %% [markdown]
# - get_group(내가 원하는 그룹)

# %%
grouped.get_group('First')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 11          1       1  female  58.0      0      0  26.5500        S  First
# 23          1       1    male  28.0      0      0  35.5000        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
# ...

# %% [markdown]
# - group 그룹을 두 개 이상 진행하게 되면
# - []

# %%
groups=tt.groupby(['class', 'embarked'])

# %%
groups

# %%
for i, j in groups:
    print(i)
    print(j.head(10))
# Out:
# ('First', 'C')
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 1           1       1  female  38.0      1      0   71.2833        C  First
# 30          0       1    male  40.0      0      0   27.7208        C  First
# 31          1       1  female   NaN      1      0  146.5208        C  First
# 34          0       1    male  28.0      1      0   82.1708        C  First
# 52          1       1  female  49.0      1      0   76.7292        C  First
# 54          0       1    male  65.0      0      1   61.9792        C  First
# 64          0       1    male   NaN      0      0   27.7208        C  First
# 96          0       1    male  71.0      0      0   34.6542        C  First
# 97          1       1    male  23.0      0      1   63.3583        C  First
# 118         0       1    male  24.0      0      1  247.5208        C  First
#
#        who  adult_male deck embark_town alive  alone  sex_onehot  fare_100
# ...

# %%
# 버전이 맞지 않으면 오류가 발생한다.
groups.mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# ...

# %%
# 따라서 다음과 같은 조건을 추가해주자!
groups.mean(numeric_only=True)
# Out:
#                  survived  pclass        age     sibsp     parch        fare  \
# class  embarked
# First  C         0.694118     1.0  38.027027  0.376471  0.317647  104.718529
#        Q         0.500000     1.0  38.500000  1.500000  0.000000   90.000000
#        S         0.582677     1.0  38.152037  0.433071  0.393701   70.364862
# Second C         0.529412     2.0  22.766667  0.588235  0.529412   25.358335
#        Q         0.666667     2.0  43.500000  0.000000  0.000000   12.350000
#        S         0.463415     2.0  30.386731  0.390244  0.371951   20.327439
# Third  C         0.378788     3.0  20.741951  0.348485  0.378788   11.214083
#        Q         0.375000     3.0  25.937500  0.416667  0.180556   11.183393
#        S         0.189802     3.0  25.696552  0.705382  0.439093   14.644083
#
#                  adult_male     alone  sex_onehot      fare_100
# class  embarked
# First  C           0.494118  0.482353    0.505882  10471.852941
# ...

# %%
# 마찬가지로 오류가 발생한다.
groups.std()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 groups.std()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1961, in GroupBy.std(self, ddof, engine, engine_kwargs, numeric_only)
#    1958         return FloatingArray(np.sqrt(vals), result_mask.view(np.bool_))
#    1959     return np.sqrt(vals)
# -> 1961 result = self._get_cythonized_result(
#    1962     libgroupby.group_var,
#    1963     cython_dtype=np.dtype(np.float64),
#    1964     numeric_only=numeric_only,
#    1965     needs_counts=True,
#    1966     pre_processing=_preprocessing,
#    1967     post_processing=_postprocessing,
#    1968     ddof=ddof,
#    1969     how="std",
#    1970 )
#    1971 return result
#
# ...

# %%
# 똑같이 수치형 데이터가 출력될 수 있게 조건을 추가해주자!
groups.std(numeric_only=True)
# Out:
#                  survived  pclass        age     sibsp     parch       fare  \
# class  embarked
# First  C         0.463515     0.0  14.243454  0.533998  0.601818  99.093935
#        Q         0.707107     0.0   7.778175  0.707107  0.000000   0.000000
#        S         0.495070     0.0  15.315584  0.649671  0.757581  58.811278
# Second C         0.514496     0.0  10.192551  0.507300  0.874475  11.345067
#        Q         0.577350     0.0  19.091883  0.000000  0.000000   0.000000
#        S         0.500187     0.0  14.080001  0.611868  0.675200  13.630741
# Third  C         0.488802     0.0  11.712367  0.594654  0.674027   4.871528
#        Q         0.487520     0.0  16.807938  0.989380  0.678158   6.721677
#        S         0.392701     0.0  12.110906  1.529408  0.954863  13.276609
#
#                  adult_male     alone  sex_onehot     fare_100
# class  embarked
# First  C           0.502933  0.502654    0.502933  9909.393497
# ...

# %% [markdown]
# - groupby agg 함수를 넣어서 통계치를 살펴본다.
#
# - group 그룹을 묶고 내가 원하는 통계치등을 정리해서 볼 수 있다.
#
# - tt.groupby('그룹할컬럼1').agg(변수명 = ('기준컬럼1', '기준컬럼을 볼 통계치', 추가추가....)

# %%
tt.groupby('class').agg(fare_sum = ('fare', 'sum'))
# Out:
#           fare_sum
# class
# First   18177.4125
# Second   3801.8417
# Third    6714.6951

# %%
# 1개의 컬럼의 2개 이상 통계치를 볼 때
grouped.agg({'fare': ['sum', 'median', 'mean', 'std', 'var']})
# Out:
#               fare
#                sum   median       mean        std          var
# class
# First   18177.4125  60.2875  84.154687  78.380373  6143.482816
# Second   3801.8417  14.2500  20.662183  13.417399   180.026589
# Third    6714.6951   8.0500  13.675550  11.778142   138.724622

# %%
tt.groupby('class').agg(fare_sum = ('fare', 'sum'),
                        fare_mean = ('fare', 'mean'),
                        fare_median = ('fare', 'median'),
                        n_cnt = ('fare', 'count'))
# Out:
#           fare_sum  fare_mean  fare_median  n_cnt
# class
# First   18177.4125  84.154687      60.2875    216
# Second   3801.8417  20.662183      14.2500    184
# Third    6714.6951  13.675550       8.0500    491

# %% [markdown]
# - 나만의 튜닝으로 만든 함수를 agg에 넣어서 값을 계산하자!

# %% [markdown]
# ## 데이터 병합
#
# - concat, merge
# - concat : 덩어리와 덩어리가 합쳐진다. df1, df2 합쳐진다. 날 것 그대로
#    - 행으로 붙이는 것 df1 + df2
#    - 열로 붙이는 것
#    - df1
#    - '+'
#    - df2
# - merge : join 형태, left, outer, right join 개념

# %%
# 데이터프레임으로 만들어서 두 문법의 원리를 이해해보자!
test1 = pd.DataFrame({'학회원번호' : [1, 2, 3, 4, 5],
                      '학회원분반' : ['Python', 'SQL', 'R', '데이터분석입문', '데이터분석전처리']})

# %%
test1
# Out:
#    학회원번호     학회원분반
# 0      1    Python
# 1      2       SQL
# 2      3         R
# 3      4   데이터분석입문
# 4      5  데이터분석전처리

# %%
# 데이터프레임으로 만들어서 두 문법의 원리를 이해해보자!
test2 = pd.DataFrame({'학회원번호' : [1, 2, 3, 4, 5],
                      '벌점현황' : [5, 5, 10, 0, 3]})

# %%
# pd.merge(왼쪽컬럼(기준), 오른쪽컬럼(그다음), how='병합방법', on='공통기준컬럼')
# left_on, right_on 지정할 수 있음
pd.merge(test1, test2, how='inner', on='학회원번호')
# Out:
#    학회원번호     학회원분반  벌점현황
# 0      1    Python     5
# 1      2       SQL     5
# 2      3         R    10
# 3      4   데이터분석입문     0
# 4      5  데이터분석전처리     3

# %%
# pd.concat을 이용해서 데이터 병합
# pd.concat(axis = 1, 0에 따라 달라진다. 1 오른쪽으로 붙여진다. 0 컬럼별로 붙여진다.)
pd.concat([test1, test2], axis=0) # 컬럼 기준 위아래 붙여진다.
# Out:
#    학회원번호     학회원분반  벌점현황
# 0      1    Python   NaN
# 1      2       SQL   NaN
# 2      3         R   NaN
# 3      4   데이터분석입문   NaN
# 4      5  데이터분석전처리   NaN
# 0      1       NaN   5.0
# 1      2       NaN   5.0
# 2      3       NaN  10.0
# 3      4       NaN   0.0
# 4      5       NaN   3.0

# %%
pd.concat([test1,test2], axis=1) # 인덱스 기준 위아래 붙여진다. # 행 열
# Out:
#    학회원번호     학회원분반  학회원번호  벌점현황
# 0      1    Python      1     5
# 1      2       SQL      2     5
# 2      3         R      3    10
# 3      4   데이터분석입문      4     0
# 4      5  데이터분석전처리      5     3

# %% [markdown]
# - value_counts()
# - 변수들의 카운팅을 진행하는 문법
# - tt.value_counts()
#
# - value_counts(normalize= True, False) 카운팅 총섬 1 나누는 것
# - value_counts(ascending= True, False) 카운트 숫자를 기준으로 내림 오름차순

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
tt.sex.value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
tt.age.value_counts(ascending=True)
# Out:
# age
# 74.0     1
# 14.5     1
# 70.5     1
# 12.0     1
# 36.5     1
#         ..
# 30.0    25
# 19.0    25
# 18.0    26
# 22.0    27
# 24.0    30
# Name: count, Length: 88, dtype: int64

# %%
tt.sex.value_counts(normalize=True)
# Out:
# sex
# male      0.647587
# female    0.352413
# Name: proportion, dtype: float64
